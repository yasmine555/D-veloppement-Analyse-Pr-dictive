# %%
from Sales_Forecasting import get_sales_data_from_api, create_features, load_model
import matplotlib.pyplot as plt

# Charger les données
df = get_sales_data_from_api()
X, y = create_features(df)

# Visualiser les données
plt.figure(figsize=(12,5))
plt.plot(df['date'], y, label='Ventes réelles')
plt.title("Évolution des ventes")
plt.xlabel("Date")
plt.ylabel("Ventes")
plt.legend()
plt.grid(True)
plt.show()

# Charger le modèle et prédire
model = load_model()
y_pred = model.predict(X)

# Visualiser prédictions
plt.figure(figsize=(12,5))
plt.plot(df['date'], y, label='Réel')
plt.plot(df['date'], y_pred, label='Prédit', linestyle='--')
plt.title("Prévision vs Réalité")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 19
#      16 plt.show()
#      18 # Charger le modèle et prédire
# ---> 19 model = load_model()
#      20 y_pred = model.predict(X)
#      22 # Visualiser prédictions
#
# File c:\projet_stage_ete_2025\forecast_sales\Sales_Forecasting.py:44, in load_model(path)
#      42 def load_model(path='app_streamlit/models/sales_model.pkl'):
#      43     """Charge un modèle existant."""
# ---> 44     return joblib.load(path)
#
# File c:\projet_stage_ete_2025\.venv\Lib\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
#     743                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'app_streamlit/models/sales_model.pkl'
