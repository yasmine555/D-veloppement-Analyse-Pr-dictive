# %%
# 🔧 Correction pour que Jupyter trouve le dossier 'src'
import sys
import os
sys.path.append(os.path.abspath("../src"))

# 📦 Imports
from telco_loader import load_telco_dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 🧹 Charger les données
df = load_telco_dataset("../data/WA_Fn_UseC_Telco_Customer_Churn.csv")

# 👀 Aperçu
print("Dimensions :", df.shape)
df.head()
# Out:
# Dimensions : (7032, 21)
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             0  No phone service             DSL             No  ...
# 1             1                No             DSL            Yes  ...
# 2             1                No             DSL            Yes  ...
# 3             0  No phone service             DSL            Yes  ...
# 4             1                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#Répartition du churn (Yes/No)
sns.countplot(x="Churn", data=df)
plt.title("Répartition des clients : Churn vs Non-Churn")
plt.xlabel("Churn")
plt.ylabel("Nombre de clients")
plt.show()

#Churn selon le contrat

sns.countplot(x="Churn", hue="Contract", data=df)
plt.title("Churn selon le type de contrat")
plt.xlabel("Churn")
plt.ylabel("Nombre de clients")
plt.xticks([0, 1], ["Non", "Oui"])
plt.show()

# %%
#3. Heatmap de corrélations numériques

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Corrélations numériques")
plt.show()

# %%
#4. Âge du client (tenure) et churn

sns.histplot(data=df, x="tenure", hue="Churn", bins=30, kde=True)
plt.title("Distribution de l'ancienneté client (tenure) selon churn")
plt.show()
